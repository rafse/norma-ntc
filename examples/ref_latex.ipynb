# %%
from pyntc.actions import bridge_braking_force_road
from pyntc.core.reference import get_ntc_ref
from IPython.display import Math

result = bridge_braking_force_road(Q_1k=300, q_1k=9, w_1=3, L=20)
ref = get_ntc_ref(bridge_braking_force_road)
Math(ref.latex)

print(f"Risultato: {result} kN")
print(f"Riferimento: {ref}")
print(f"LaTeX: {ref.latex}")
# Out:
# Risultato: 414.0 kN
# Riferimento: NTC18 §5.1.3.5 - [5.1.4]
# LaTeX: 180 \leq q_3 = 0{,}6 \cdot 2Q_{1k} + 0{,}10 \cdot q_{1k} \cdot w_1 \cdot L \leq 900 \; [\text{kN}]

# %% [markdown]
# $$ 180 \leq q_3 = 0{,}6 \cdot 2Q_{1k} + 0{,}10 \cdot q_{1k} \cdot w_1 \cdot L \leq 900 \; [\text{kN}]
